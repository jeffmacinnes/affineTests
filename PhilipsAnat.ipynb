# %%
import os
from os.path import join

import numpy as np
import glob
import re
import nibabel as nib

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
seriesDir = 'data/Philips'

# %%
anatPar = glob.glob(join(seriesDir, '*.PAR'))

# %%
anatPar
# Out:
# ['data/Philips/MPRAGE_S2_SENSE_8_1.PAR']

# %%
testImg = nib.load(anatPar[0], strict_sort=True)

# %%
testImg.shape
# Out:
# (256, 256, 176)

# %%
plt.imshow(testImg.get_data()[:,:,100], cmap='bone')

# %%
nib.aff2axcodes(testImg.affine)
# Out:
# ('P', 'I', 'R')

# %%
testImg_RAS = nib.as_closest_canonical(testImg)

# %%
nib.aff2a
